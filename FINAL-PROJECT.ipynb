# %%
#FROM FRANCELLE - Gets USD value of 321 cryptocurrencies
import json
key = "https://api.binance.com/api/v3/ticker/price?symbol=" #Defining Binance API URL

# Making list for multiple crypto's
currencies = {"BTC":"BTCUSDT",
"ETH":"ETHUSDT",
"USDC":"USDCUSDT",
"BNB":"BNBUSDT",
"BUSD":"BUSDUSDT",
"XRP":"XRPUSDT",
"ADA":"ADAUSDT",
"SOL":"SOLUSDT",
"DOGE":"DOGEUSDT",
"DOT":"DOTUSDT",
"MATIC":"MATICUSDT",
"AVAX":"AVAXUSDT",
"SHIB":"SHIBUSDT",
"TRX":"TRXUSDT",
"UNI":"UNIUSDT",
"LTC":"LTCUSDT",
"FTT":"FTTUSDT",
"LINK":"LINKUSDT",
"ETC":"ETCUSDT",
"NEAR":"NEARUSDT",
"XLM":"XLMUSDT",
"ATOM":"ATOMUSDT",
"XMR":"XMRUSDT",
"ALGO":"ALGOUSDT",
"BCH":"BCHUSDT",
"ICP":"ICPUSDT",
"APE":"APEUSDT",
"VET":"VETUSDT",
"FLOW":"FLOWUSDT",
"MANA":"MANAUSDT",
"SAND":"SANDUSDT",
"XTZ":"XTZUSDT",
"HBAR":"HBARUSDT",
"EGLD":"EGLDUSDT",
"FIL":"FILUSDT",
"AAVE":"AAVEUSDT",
"AXS":"AXSUSDT",
"THETA":"THETAUSDT",
"QNT":"QNTUSDT",
"TUSD":"TUSDUSDT",
"HNT":"HNTUSDT",
"EOS":"EOSUSDT",
"MKR":"MKRUSDT",
"ZEC":"ZECUSDT",
"BTTC":"BTTCUSDT",
"RUNE":"RUNEUSDT",
"IOTA":"IOTAUSDT",
"XEC":"XECUSDT",
"GRT":"GRTUSDT",
"KLAY":"KLAYUSDT",
"FTM":"FTMUSDT",
"NEO":"NEOUSDT",
"CHZ":"CHZUSDT",
"CRV":"CRVUSDT",
"GMT":"GMTUSDT",
"BAT":"BATUSDT",
"WAVES":"WAVESUSDT",
"PAXG":"PAXGUSDT",
"LRC":"LRCUSDT",
"AR":"ARUSDT",
"STX":"STXUSDT",
"ZIL":"ZILUSDT",
"DASH":"DASHUSDT",
"KSM":"KSMUSDT",
"ENJ":"ENJUSDT",
"CAKE":"CAKEUSDT",
"LDO":"LDOUSDT",
"CVX":"CVXUSDT",
"CELO":"CELOUSDT",
"KAVA":"KAVAUSDT",
"MINA":"MINAUSDT",
"COMP":"COMPUSDT",
"1INCH":"1INCHUSDT",
"XEM":"XEMUSDT",
"GALA":"GALAUSDT",
"AMP":"AMPUSDT",
"HOT":"HOTUSDT",
"DCR":"DCRUSDT",
"NEXO":"NEXOUSDT",
"TFUEL":"TFUELUSDT",
"QTUM":"QTUMUSDT",
"BTG":"BTGUSDT",
"KDA":"KDAUSDT",
"SNX":"SNXUSDT",
"T":"TUSDT",
"IOTX":"IOTXUSDT",
"RVN":"RVNUSDT",
"ROSE":"ROSEUSDT",
"AUDIO":"AUDIOUSDT",
"SRM":"SRMUSDT",
"ONE":"ONEUSDT",
"STORJ":"STORJUSDT",
"ZRX":"ZRXUSDT",
"OMG":"OMGUSDT",
"JST":"JSTUSDT",
"ICX":"ICXUSDT",
"ALPHA":"ALPHAUSDT",
"POLS":"POLSUSDT",
"SUPER":"SUPERUSDT",
"FORTH":"FORTHUSDT",
"BOND":"BONDUSDT",
"RAD":"RADUSDT",
"MLN":"MLNUSDT",
"DUSK":"DUSKUSDT",
"TOMO":"TOMOUSDT",
"BAND":"BANDUSDT",
"FLM":"FLMUSDT",
"BETA":"BETAUSDT",
"YFII":"YFIIUSDT",
"COCOS":"COCOSUSDT",
"IDEX":"IDEXUSDT",
"POND":"PONDUSDT",
"MBOX":"MBOXUSDT",
"BADGER":"BADGERUSDT",
"ARPA":"ARPAUSDT",
"TRU":"TRUUSDT",
"MASK":"MASKUSDT",
"ORN":"ORNUSDT",
"JASMY":"JASMYUSDT",
"MFT":"MFTUSDT",
"MITH":"MITHUSDT",
"REI":"REIUSDT",
"WAN":"WANUSDT",
"ANC":"ANCUSDT",
"MC":"MCUSDT",
"BTS":"BTSUSDT",
"BEL":"BELUSDT",
"TROY":"TROYUSDT",
"GTC":"GTCUSDT",
"KMD":"KMDUSDT",
"LTO":"LTOUSDT",
"BURGER":"BURGERUSDT",
"ALCX":"ALCXUSDT",
"TVK":"TVKUSDT",
"SFP":"SFPUSDT",
"TRB":"TRBUSDT",
"DIA":"DIAUSDT",
"LINA":"LINAUSDT",
"ALPACA":"ALPACAUSDT",
"TKO":"TKOUSDT",
"BLZ":"BLZUSDT",
"CLV":"CLVUSDT",
"FARM":"FARMUSDT",
"PHA":"PHAUSDT",
"HARD":"HARDUSDT",
"AVA":"AVAUSDT",
"BIFI":"BIFIUSDT",
"LIT":"LITUSDT",
"ATA":"ATAUSDT",
"DNT":"DNTUSDT",
"COS":"COSUSDT",
"IRIS":"IRISUSDT",
"FIRO":"FIROUSDT",
"ALPINE":"ALPINEUSDT",
"AGLD":"AGLDUSDT",
"FIO":"FIOUSDT",
"UNFI":"UNFIUSDT",
"CTXC":"CTXCUSDT",
"ERN":"ERNUSDT",
"KP3R":"KP3RUSDT",
"CHESS":"CHESSUSDT",
"RARE":"RAREUSDT",
"ADX":"ADXUSDT",
"DATA":"DATAUSDT",
"WNXM":"WNXMUSDT",
"TORN":"TORNUSDT",
"QUICK":"QUICKUSDT",
"AKRO":"AKROUSDT",
"OM":"OMUSDT",
"VOXEL":"VOXELUSDT",
"FIDA":"FIDAUSDT",
"FRONT":"FRONTUSDT",
"NULS":"NULSUSDT",
"KEY":"KEYUSDT",
"FIS":"FISUSDT",
"BEAM":"BEAMUSDT",
"DREP":"DREPUSDT",
"PSG":"PSGUSDT",
"MDT":"MDTUSDT",
"GTO":"GTOUSDT",
"LAZIO":"LAZIOUSDT",
"HIGH":"HIGHUSDT",
"WTC":"WTCUSDT",
"DF":"DFUSDT",
"AION":"AIONUSDT",
"DOCK":"DOCKUSDT",
"DEXE":"DEXEUSDT",
"DODO":"DODOUSDT",
"SANTOS":"SANTOSUSDT",
"OOKI":"OOKIUSDT",
"LOKA":"LOKAUSDT",
"BAR":"BARUSDT",
"PNT":"PNTUSDT",
"CITY":"CITYUSDT",
"PORTO":"PORTOUSDT",
"VIDT":"VIDTUSDT",
"AUTO":"AUTOUSDT",
"CVP":"CVPUSDT",
"VITE":"VITEUSDT",
"WING":"WINGUSDT",
"DEGO":"DEGOUSDT",
"FOR":"FORUSDT",
"MIR":"MIRUSDT",
"AUCTION":"AUCTIONUSDT",
"NBS":"NBSUSDT",
"PERL":"PERLUSDT",
"TCT":"TCTUSDT",
"ACM":"ACMUSDT",
"ATM":"ATMUSDT",
"ASR":"ASRUSDT",
"QI":"QIUSDT",
"JUV":"JUVUSDT",
"OG":"OGUSDT",
"GNO":"GNOUSDT",
"EPX":"EPXUSDT",
"MULTI":"MULTIUSDT",
"OP":"OPUSDT",
"GBP":"GBPUSDT",
"LEVER":"LEVERUSDT"}

#RANDOM

crypto_USD_value = 0

#FROM JU

import requests

url = 'https://api.exchangerate.host/latest'
response = requests.get(url)
dict = response.json()
rates = dict['rates']
keys = list(rates.keys())

#DISCORD BOT

import nest_asyncio
nest_asyncio.apply()
import discord
from discord.ext import commands

TOKEN = 'OTk4NTU0Mzk4NzE0MjM2OTU5.GAfl10.n9M0zUi9vIyHS2pQRM3Lf0QlpL2SNSxxiEzEkw'

client = commands.Bot(command_prefix="!", intents=discord.Intents.all())
client.remove_command("help")

@client.event 
async def on_ready():
    print("We have logged in as {0.user}".format(client))

#Input from discord
@client.event
async def currency(ctx,*args):
  currency = "" #Get the user message ( without the command !msg )
  await ctx.channel.send(currency)  

@client.command()
async def currency(ctx, x, convert_to):
    x.upper()
    convert_to.upper()
    def find_crypto_value():
        if x in list(currencies.keys()):
            # completing API for request
            url = key+currencies[x] 
            data = requests.get(url)
            data = data.json()
            cryptoindex = (list(currencies.keys()).index(x))
            cryptovalues = list(currencies.values())
            name = cryptovalues[cryptoindex]
            response = f"{name.replace('USDT','')} price is ${data['price']}"
            
            #Store coin value in USD
            crypto_USD_value = data['price']

            return crypto_USD_value 

        else:
            response = "I'm sorry, there may be a mistake in your input or we may not have the currency you are trying to convert in our system."
            return response
    
    crypto_USD_value = find_crypto_value()      

    #LONG CODE
    def message_change():
        if len(str(crypto_USD_value)) != 120:
            initial_money = round(float(crypto_USD_value),2)
        else:
            return crypto_USD_value
        first_curr = 'USD'
        second_curr = convert_to
        if first_curr in keys and second_curr in keys:
            eur = rates[first_curr]
            convert = round(rates[second_curr]/eur,2)
            converted_money = initial_money * convert                
            response =(f'{x} price is {second_curr} {round(converted_money,2)}')
            return response
        else:
            response = f"I'm sorry {ctx.author.mention}, we may not have the currency you are trying to convert."
            return response

    await ctx.send(message_change())

@client.command()
async def help(ctx):
    string = "`!currency [cryptocurrency] [currency]` - Convert crypto into a real world currency."
    await ctx.send(string)

client.run(TOKEN)
# Out:
# We have logged in as Currency_Bot#8600
# Unclosed connection
# client_connection: Connection<ConnectionKey(host='gateway.discord.gg', port=443, is_ssl=True, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=None)>
# We have logged in as Currency_Bot#8600
# Unclosed connection
# client_connection: Connection<ConnectionKey(host='gateway.discord.gg', port=443, is_ssl=True, ssl=None, proxy=None, proxy_auth=None, proxy_headers_hash=None)>
# We have logged in as Currency_Bot#8600
# We have logged in as Currency_Bot#8600
